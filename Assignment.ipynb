# %% [markdown]
# # Basic Python

# %% [markdown]
# ## 1. Split this string

# %%
s = "Hi there Sam!"

# %%
s="Hi there Sam!"
split =s.split(',')
print(split)
# Out:
# ['Hi there Sam!']

# %% [markdown]
# ## 2. Use .format() to print the following string.
#
# ### Output should be: The diameter of Earth is 12742 kilometers.

# %%
planet = "Earth"
diameter = 12742

# %%
print('The diameter of {one} is {two} kilometers'.format (one=planet,two=diameter))
# Out:
# The diameter of Earth is 12742 kilometers

# %% [markdown]
# ## 3. In this nest dictionary grab the word "hello"

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
print(d['k1'][3]["tricky"][3]['target'][3])
# Out:
# hello

# %% [markdown]
# ## 2. Use .format() to print the following string.
#
# ### Output should be: The diameter of Earth is 12742 kilometers.

# %% [markdown]
# # Numpy

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ## 4.1 Create an array of 10 zeros?
# ## 4.2 Create an array of 10 fives?

# %%
import numpy as np
array =np.zeros(10)
print(array)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 import numpy as np
#       2 array =np.zeros(10)
#       3 print(array)
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np
array=np.ones(10)*5
print(array)

# %% [markdown]
# ## 5. Create an array of all the even integers from 20 to 35

# %%
import numpy as np
array_even=np.arange(20,35,2)
print(array_even)

# %% [markdown]
# ## 6. Create a 3x3 matrix with values ranging from 0 to 8

# %%
import numpy as np
matrix=np.arange(0,8).reshape(3,3)
print(matrix)

# %% [markdown]
# ## 7. Concatenate a and b
# ## a = np.array([1, 2, 3]), b = np.array([4, 5, 6])

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
array_append=numpy.concatenate([a,b])
print(array_append)

# %% [markdown]
# # Pandas

# %% [markdown]
# ## 8. Create a dataframe with 3 rows and 2 columns

# %%
import pandas as pd

# %%
import pandas as pd
list=[[1,2,3,4,5,6,7,8,9]]
list_1=list[0][:3]
list_2=list[0][:3]
list_3=list[0][:3]
DataFrame=pd.DataFrame([list_1,list_2,list_3],colums=['l1','l2','l3'])

# %% [markdown]
# ## 9. Generate the series of dates from 1st Jan, 2023 to 10th Feb, 2023

# %%
import pandas as pd
from datetime import datetime
dates=pd.date_range(start="2023-01-01",end="2023-02-10").to_pydatetime().tolist()
print(dates)

# %% [markdown]
# ## 10. Create 2D list to DataFrame
#
# lists = [[1, 'aaa', 22],
#          [2, 'bbb', 25],
#          [3, 'ccc', 24]]

# %%
lists = [[1, 'aaa', 22], [2, 'bbb', 25], [3, 'ccc', 24]]

# %%
import pandas as pd
lists = [[1, 'aaa', 22], [2, 'bbb', 25], [3, 'ccc', 24]]
DataFrame=pd.DataFrame([lists1,lists2,lists3],columns=['l1','l2','l3'])
print(DataFrame)
